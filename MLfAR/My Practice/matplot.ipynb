# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
fig = plt.figure()
fig

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# %%
fig = plt.figure()
_ = fig.add_subplot(241) #2 rows, 4 columns, 1st slot
_ = fig.add_subplot(244)
_ = fig.add_subplot(246)
_ = fig.add_subplot(248)

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1)

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 4)

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 4)
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 4, figsize =(10, 4)) # height of figure
fig.tight_layout()

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1)

# %%
ax.set_xlim([0.5, 4.5])
ax.set_ylim([-2, 8])
ax.set_title("An Example Axes")
ax.set_ylabel("Y-axis")
ax.set_xlabel("X-axis")
# Out:
# Text(0.5, 4.444444444444445, 'X-axis')

# %%
fig

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

_ = ax.set(
    xlim=[0.5, 4.5],
    ylim=[-2, 8],
    title="An example axes",
    ylabel="Y-axis",
    xlabel="X-axis",
)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
ax.plot([1, 2, 3, 4],[10, 20, 25, 40])

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
ax.scatter([1, 2, 3, 4],[10, 20, 25, 40])

# %%
ax.plot([1, 2, 3, 4],[65, 34, 12, -12])
fig

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize= (6,4))
fig.tight_layout()

# %%
print(type(axes))
print(type(axes[0,0]))
# Out:
# <class 'numpy.ndarray'>
# <class 'matplotlib.axes._axes.Axes'>

# %%
axes[0, 0].plot([1, 2, 3, 4], [10, 20, 25, 35])
fig

# %%
axes[0, 1].plot([1, 2, 3, 4], [65, 34, 12, -12])
fig

# %%
axes[0, 0].set(title = "Upper Left")
axes[0, 1].set(title = "Upper Right")
axes[1, 0].set(title = "Lower Left")
axes[1, 1].set(title = "Lower Right")
fig.suptitle("Four Subplots")
fig.tight_layout()
fig

# %%
plt.figure()
plt.plot([10, 20, 25, 35])
plt.show()
